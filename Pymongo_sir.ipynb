# %%
## Importing MongoClient from pymongo Module

from pymongo import MongoClient

# %%
client = MongoClient("mongodb+srv://m001-student:amey@sandbox.gmtc6.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")

# %%
database = client['Sample_training']

# %%
t = database.trips

# %%
print(trips.find_one())
# Out:
# None

# %%
for i in reviews.find().limit(5):
    print(i)

# %%
## Direct Search
for i in reviews.find({"name":"VIZIO 55-in Class OLED 4K HDR Smart TV OLED55-H1"}):
    print(i)

# %%
## Using Operators in query

for records in reviews.find({"rating":{"$gt":4}}):
    print(records)
len(records)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-8c494715c891> in <module>
#       3 for records in reviews.find({"rating":{"$gt":4}}):
#       4     print(records)
# ----> 5 len(records)
#
# NameError: name 'records' is not defined

# %%
### GroupBy in PyMongo

gb_result = reviews.aggregate([{"$group":{"_id":"$brand","Total":{"$sum":1}}}])

# %%
for records in gb_result:
    print(records)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-e311f5a4963c> in <module>
# ----> 1 for records in gb_result:
#       2     print(records)
#
# NameError: name 'gb_result' is not defined

# %%
for records in reviews.aggregate([{"$project":{"brand":1,"reviewer_name":1,"rating":1}}]):
    print(records)
# Out:
# {'_id': ObjectId('61e709697ceb7ef1efd6a14f'), 'brand': 'VIZIO', 'reviewer_name': 'Leeford', 'rating': 5.0}
# {'_id': ObjectId('61e709697ceb7ef1efd6a150'), 'brand': 'VIZIO', 'reviewer_name': 'DJM7', 'rating': 4.0}
# {'_id': ObjectId('61e709697ceb7ef1efd6a151'), 'brand': 'VIZIO', 'reviewer_name': 'EC82', 'rating': 4.0}
# {'_id': ObjectId('61e709697ceb7ef1efd6a152'), 'brand': 'VIZIO', 'reviewer_name': 'Weeto', 'rating': 2.0}
# {'_id': ObjectId('61e709697ceb7ef1efd6a153'), 'brand': 'VIZIO', 'reviewer_name': 'LexusSC400', 'rating': 5.0}
# {'_id': ObjectId('61e709697ceb7ef1efd6a154'), 'brand': 'VIZIO', 'reviewer_name': 'Ninjaafro', 'rating': 3.0}
# {'_id': ObjectId('61e709697ceb7ef1efd6a155'), 'brand': 'VIZIO', 'reviewer_name': 'von R', 'rating': 5.0}
# {'_id': ObjectId('61e709697ceb7ef1efd6a156'), 'brand': 'VIZIO', 'reviewer_name': 'Ohio Erik', 'rating': 5.0}
# {'_id': ObjectId('61e709697ceb7ef1efd6a157'), 'brand': 'VIZIO', 'reviewer_name': 'jonck', 'rating': 4.0}
# ...
